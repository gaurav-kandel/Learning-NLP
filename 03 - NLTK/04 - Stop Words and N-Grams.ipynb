# %% [markdown]
# ***
# Welcome!
#
# In this notebook, we will explore the impact of Stop Words on a specific piece of text. Stop Words are common words like "and," "the," and "is" that often don't contribute much meaning to a sentence. By understanding how these words can be removed or filtered out, we can improve the clarity and focus of our text.
#
# Additionally, we will dive into the concept of N-Grams. N-Grams are simply sequences of words, and by analyzing these sequences, we can uncover patterns and relationships within our text. This can help us gain insights into how words are used together and how they contribute to the overall meaning.
# <br>
# ***

# %% [markdown]
# ### Index:

# %% [markdown]
# [1.1 - Stop Words](#1.1---Stop-Words)
# <br>
# [1.2 - N-Grams](#1.2---N-Grams)

# %%
import nltk

# %% [markdown]
# Let's start by defining a long sentence - this time we will use an excerpt from J.R.R Tolkien's book 'The Lord of the Rings':

# %%
lotr_quote = '''
‘I cannot read the fiery letters,’ said Frodo in a quavering
voice.
‘No,’ said Gandalf, ‘but I can. The letters are Elvish, of an
ancient mode, but the language is that of Mordor, which I
will not utter here. But this in the Common Tongue is what
is said, close enough:
One Ring to rule them all, One Ring to find them,
One Ring to bring them all and in the darkness bind them.
It is only two lines of a verse long known in Elven-lore:
Three Rings for the Elven-kings under the sky,
Seven for the Dwarf-lords in their halls of stone,
Nine for Mortal Men doomed to die,
One for the Dark Lord on his dark throne
In the Land of Mordor where the Shadows lie.
One Ring to rule them all, One Ring to find them,
One Ring to bring them all and in the darkness bind them
In the Land of Mordor where the Shadows lie.’
He paused, and then said slowly in a deep voice: ‘This is
the Master-ring, the One Ring to rule them all. This is the
One Ring that he lost many ages ago, to the great weakening
the shadow of the past 67
of his power. He greatly desires it – but he must not get it.’
Frodo sat silent and motionless. Fear seemed to stretch out
a vast hand, like a dark cloud rising in the East and looming
up to engulf him. ‘This ring!’ he stammered. ‘How, how on
earth did it come to me?’

'''

# %% [markdown]
# ### 1.1 - Stop Words

# %% [markdown]
# ***
# A lot of words in a sentence don't mean much - they are filler words that are used to connect sentences and in some (not all!) applications with Natural Language Processing, we can remove them.
# <br>
# These types of words are commonly called *stop words*.
# <br>
# ***

# %% [markdown]
# **NLTK let us access the English Language Stop words really quickly:**

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gauravkandel/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# By using stopwords.words we access common stop words
stopwords_eng = stopwords.words('English')

# %%
stopwords_eng
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Let us tokenize our quote from the Lord of the Rings
# and use Freq Dist that we have already learned
word_frequency = nltk.FreqDist(nltk.tokenize.word_tokenize(lotr_quote))

# %%
word_frequency.most_common(10)
# Out:
# [('the', 20),
#  (',', 19),
#  ('to', 12),
#  ('.', 10),
#  ('One', 9),
#  ('them', 9),
#  ('in', 8),
#  ('of', 8),
#  ('Ring', 8),
#  ('‘', 6)]

# %% [markdown]
# Our top words don't mean much - we have *the*, *to*, *them*, *in* and *of*, some very common English words. This is a pattern that you will encounter throughout a lot of different texts - for example, let's pass a really different text into this process to check the top words:

# %%
# Let's use a quote from Apple's Annual Report from 2020:
apple_annual_report = '''
The Company’s stock price has experienced substantial price volatility in the past and may continue to do so in the future.
Additionally, the Company, the technology industry and the stock market as a whole have experienced extreme stock price and
volume fluctuations that have affected stock prices in ways that may have been unrelated to these companies’ operating
performance. Price volatility over a given period may cause the average price at which the Company repurchases its stock to
exceed the stock’s price at a given point in time. The Company believes its stock price should reflect expectations of future
growth and profitability. The Company also believes its stock price should reflect expectations that its cash dividend will continue
at current levels or grow, and that its current share repurchase program will be fully consummated. Future dividends are subject
to declaration by the Company’s Board of Directors, and the Company’s share repurchase program does not obligate it to
acquire any specific number of shares. If the Company fails to meet expectations related to future growth, profitability, dividends,
share repurchases or other market expectations, its stock price may decline significantly, which could have a material adverse
impact on investor confidence and employee retention.
'''

# %%
word_frequency_apple = nltk.FreqDist(nltk.tokenize.word_tokenize(apple_annual_report))

# %%
word_frequency_apple.most_common(10)
# Out:
# [('the', 11),
#  ('stock', 9),
#  (',', 9),
#  ('Company', 8),
#  ('price', 8),
#  ('and', 7),
#  ('to', 7),
#  ('.', 7),
#  ('its', 6),
#  ('’', 5)]

# %% [markdown]
# The top word in both texts is exactly the same - the word **the**.
# <br>
# <br>
# And notice how there are other words like **to** and punctuation are also shared between texts. Even for pieces of text as diverse as a lotr quote and a financial report, these are the words that stand out.
# <br>
# <br>
# Let us now build a proper text pipeline that will clean the punctuation and stop words and you will see something completely different from the `FreqDist` analysis:

# %%
# A cool tip we haven't explored yet - translate removes punctuation really fast
import string
lotr_quote = lotr_quote.translate(str.maketrans('', '', string.punctuation))

# %%
lotr_quote
# Out:
# '\n‘I cannot read the fiery letters’ said Frodo in a quavering\nvoice\n‘No’ said Gandalf ‘but I can The letters are Elvish of an\nancient mode but the language is that of Mordor which I\nwill not utter here But this in the Common Tongue is what\nis said close enough\nOne Ring to rule them all One Ring to find them\nOne Ring to bring them all and in the darkness bind them\nIt is only two lines of a verse long known in Elvenlore\nThree Rings for the Elvenkings under the sky\nSeven for the Dwarflords in their halls of stone\nNine for Mortal Men doomed to die\nOne for the Dark Lord on his dark throne\nIn the Land of Mordor where the Shadows lie\nOne Ring to rule them all One Ring to find them\nOne Ring to bring them all and in the darkness bind them\nIn the Land of Mordor where the Shadows lie’\nHe paused and then said slowly in a deep voice ‘This is\nthe Masterring the One Ring to rule them all This is the\nOne Ring that he lost many ages ago to the great weakening\nthe shadow of the past 67\nof his power He greatly desires it – but he must not get it’\nFrodo sat silent and motionless Fear seemed to stretch out\na vast hand like a dark cloud rising in the East and looming\nup to engulf him ‘This ring’ he stammered ‘How how on\nearth did it come to me’\n\n'

# %%
# Some Punctuation was not removed - let's do it manually
lotr_quote = lotr_quote.replace('’','').replace('‘','')

# %%
# Let's now remove stop words
lotr_cleaned = [
    word.lower() for word in nltk.word_tokenize(lotr_quote) if word.lower() not in stopwords_eng
]

# %%
lotr_frequency_cleaned = nltk.FreqDist(lotr_cleaned)

# %%
lotr_frequency_cleaned.most_common(10)
# Out:
# [('one', 9),
#  ('ring', 9),
#  ('said', 4),
#  ('mordor', 3),
#  ('rule', 3),
#  ('dark', 3),
#  ('letters', 2),
#  ('frodo', 2),
#  ('voice', 2),
#  ('find', 2)]

# %% [markdown]
# Just like magic, we were able to extract what is most relevant to this text and we can easily find words that are related to the lord of the rings saga:
# - Mordor;
# - Ring;
# - Frodo;

# %% [markdown]
# Now let us do the same for the Apple Annual Report Quote:

# %%
apple_annual_report = apple_annual_report.translate(str.maketrans('', '', string.punctuation))

# Let's now remove stop words
apple_cleaned = [
    word.lower() for word in nltk.word_tokenize(apple_annual_report) if word.lower() not in stopwords_eng
]

# %%
apple_frequency_cleaned = nltk.FreqDist(apple_cleaned)

# %%
apple_frequency_cleaned.most_common(10)
# Out:
# [('stock', 9),
#  ('price', 9),
#  ('company', 8),
#  ('’', 5),
#  ('may', 4),
#  ('future', 4),
#  ('expectations', 4),
#  ('share', 3),
#  ('experienced', 2),
#  ('volatility', 2)]

# %% [markdown]
# As you can see, now the top 10 words regarding the Apple Annual Report quote are more related to that piece of text.

# %% [markdown]
# ### 1.2 - N-Grams

# %% [markdown]
# Many times, you will hear people talking about `n-grams` - being `n` the number of continuous chunks we group a sentence by. This is exactly what we've spoke about in the `"Train our own POS Tagger"` lectures. Here, we are just going to consolidate this knowledge:

# %%
from nltk import bigrams, trigrams, everygrams

# %% [markdown]
# Let's continue with our Lord of The Rings quote:

# %%
lotr_quote
# Out:
# '\nI cannot read the fiery letters said Frodo in a quavering\nvoice\nNo said Gandalf but I can The letters are Elvish of an\nancient mode but the language is that of Mordor which I\nwill not utter here But this in the Common Tongue is what\nis said close enough\nOne Ring to rule them all One Ring to find them\nOne Ring to bring them all and in the darkness bind them\nIt is only two lines of a verse long known in Elvenlore\nThree Rings for the Elvenkings under the sky\nSeven for the Dwarflords in their halls of stone\nNine for Mortal Men doomed to die\nOne for the Dark Lord on his dark throne\nIn the Land of Mordor where the Shadows lie\nOne Ring to rule them all One Ring to find them\nOne Ring to bring them all and in the darkness bind them\nIn the Land of Mordor where the Shadows lie\nHe paused and then said slowly in a deep voice This is\nthe Masterring the One Ring to rule them all This is the\nOne Ring that he lost many ages ago to the great weakening\nthe shadow of the past 67\nof his power He greatly desires it – but he must not get it\nFrodo sat silent and motionless Fear seemed to stretch out\na vast hand like a dark cloud rising in the East and looming\nup to engulf him This ring he stammered How how on\nearth did it come to me\n\n'

# %%
# As usual, we have to tokenize our sentence
lotr_quote_tokenized = nltk.word_tokenize(lotr_quote)

# %%
# Let's now check our bigrams - every pair of two
# continuous words in a sentence
list(bigrams(lotr_quote_tokenized))
# Out:
# [('I', 'can'),
#  ('can', 'not'),
#  ('not', 'read'),
#  ('read', 'the'),
#  ('the', 'fiery'),
#  ('fiery', 'letters'),
#  ('letters', 'said'),
#  ('said', 'Frodo'),
#  ('Frodo', 'in'),
#  ('in', 'a'),
#  ('a', 'quavering'),
#  ('quavering', 'voice'),
#  ('voice', 'No'),
#  ('No', 'said'),
#  ('said', 'Gandalf'),
#  ('Gandalf', 'but'),
#  ('but', 'I'),
#  ('I', 'can'),
#  ('can', 'The'),
#  ('The', 'letters'),
#  ('letters', 'are'),
#  ('are', 'Elvish'),
#  ('Elvish', 'of'),
#  ('of', 'an'),
#  ('an', 'ancient'),
#  ('ancient', 'mode'),
#  ('mode', 'but'),
#  ('but', 'the'),
#  ('the', 'language'),
#  ('language', 'is'),
#  ('is', 'that'),
#  ('that', 'of'),
#  ('of', 'Mordor'),
#  ('Mordor', 'which'),
#  ('which', 'I'),
#  ('I', 'will'),
#  ('will', 'not'),
#  ('not', 'utter'),
#  ('utter', 'here'),
#  ('here', 'But'),
#  ('But', 'this'),
#  ('this', 'in'),
#  ('in', 'the'),
#  ('the', 'Common'),
#  ('Common', 'Tongue'),
#  ('Tongue', 'is'),
#  ('is', 'what'),
#  ('what', 'is'),
#  ('is', 'said'),
#  ('said', 'close'),
#  ('close', 'enough'),
#  ('enough', 'One'),
#  ('One', 'Ring'),
#  ('Ring', 'to'),
#  ('to', 'rule'),
#  ('rule', 'them'),
#  ('them', 'all'),
#  ('all', 'One'),
#  ('One', 'Ring'),
#  ('Ring', 'to'),
#  ('to', 'find'),
#  ('find', 'them'),
#  ('them', 'One'),
#  ('One', 'Ring'),
#  ('Ring', 'to'),
#  ('to', 'bring'),
#  ('bring', 'them'),
#  ('them', 'all'),
#  ('all', 'and'),
#  ('and', 'in'),
#  ('in', 'the'),
#  ('the', 'darkness'),
#  ('darkness', 'bind'),
#  ('bind', 'them'),
#  ('them', 'It'),
#  ('It', 'is'),
#  ('is', 'only'),
#  ('only', 'two'),
#  ('two', 'lines'),
#  ('lines', 'of'),
#  ('of', 'a'),
#  ('a', 'verse'),
#  ('verse', 'long'),
#  ('long', 'known'),
#  ('known', 'in'),
#  ('in', 'Elvenlore'),
#  ('Elvenlore', 'Three'),
#  ('Three', 'Rings'),
#  ('Rings', 'for'),
#  ('for', 'the'),
#  ('the', 'Elvenkings'),
#  ('Elvenkings', 'under'),
#  ('under', 'the'),
#  ('the', 'sky'),
#  ('sky', 'Seven'),
#  ('Seven', 'for'),
#  ('for', 'the'),
#  ('the', 'Dwarflords'),
#  ('Dwarflords', 'in'),
#  ('in', 'their'),
#  ('their', 'halls'),
#  ('halls', 'of'),
#  ('of', 'stone'),
#  ('stone', 'Nine'),
#  ('Nine', 'for'),
#  ('for', 'Mortal'),
#  ('Mortal', 'Men'),
#  ('Men', 'doomed'),
#  ('doomed', 'to'),
#  ('to', 'die'),
#  ('die', 'One'),
#  ('One', 'for'),
#  ('for', 'the'),
#  ('the', 'Dark'),
#  ('Dark', 'Lord'),
#  ('Lord', 'on'),
#  ('on', 'his'),
#  ('his', 'dark'),
#  ('dark', 'throne'),
#  ('throne', 'In'),
#  ('In', 'the'),
#  ('the', 'Land'),
#  ('Land', 'of'),
#  ('of', 'Mordor'),
#  ('Mordor', 'where'),
#  ('where', 'the'),
#  ('the', 'Shadows'),
#  ('Shadows', 'lie'),
#  ('lie', 'One'),
#  ('One', 'Ring'),
#  ('Ring', 'to'),
#  ('to', 'rule'),
#  ('rule', 'them'),
#  ('them', 'all'),
#  ('all', 'One'),
#  ('One', 'Ring'),
#  ('Ring', 'to'),
#  ('to', 'find'),
#  ('find', 'them'),
#  ('them', 'One'),
#  ('One', 'Ring'),
#  ('Ring', 'to'),
#  ('to', 'bring'),
#  ('bring', 'them'),
#  ('them', 'all'),
#  ('all', 'and'),
#  ('and', 'in'),
#  ('in', 'the'),
#  ('the', 'darkness'),
#  ('darkness', 'bind'),
#  ('bind', 'them'),
#  ('them', 'In'),
#  ('In', 'the'),
#  ('the', 'Land'),
#  ('Land', 'of'),
#  ('of', 'Mordor'),
#  ('Mordor', 'where'),
#  ('where', 'the'),
#  ('the', 'Shadows'),
#  ('Shadows', 'lie'),
#  ('lie', 'He'),
#  ('He', 'paused'),
#  ('paused', 'and'),
#  ('and', 'then'),
#  ('then', 'said'),
#  ('said', 'slowly'),
#  ('slowly', 'in'),
#  ('in', 'a'),
#  ('a', 'deep'),
#  ('deep', 'voice'),
#  ('voice', 'This'),
#  ('This', 'is'),
#  ('is', 'the'),
#  ('the', 'Masterring'),
#  ('Masterring', 'the'),
#  ('the', 'One'),
#  ('One', 'Ring'),
#  ('Ring', 'to'),
#  ('to', 'rule'),
#  ('rule', 'them'),
#  ('them', 'all'),
#  ('all', 'This'),
#  ('This', 'is'),
#  ('is', 'the'),
#  ('the', 'One'),
#  ('One', 'Ring'),
#  ('Ring', 'that'),
#  ('that', 'he'),
#  ('he', 'lost'),
#  ('lost', 'many'),
#  ('many', 'ages'),
#  ('ages', 'ago'),
#  ('ago', 'to'),
#  ('to', 'the'),
#  ('the', 'great'),
#  ('great', 'weakening'),
#  ('weakening', 'the'),
#  ('the', 'shadow'),
#  ('shadow', 'of'),
#  ('of', 'the'),
#  ('the', 'past'),
#  ('past', '67'),
#  ('67', 'of'),
#  ('of', 'his'),
#  ('his', 'power'),
#  ('power', 'He'),
#  ('He', 'greatly'),
#  ('greatly', 'desires'),
#  ('desires', 'it'),
#  ('it', '–'),
#  ('–', 'but'),
#  ('but', 'he'),
#  ('he', 'must'),
#  ('must', 'not'),
#  ('not', 'get'),
#  ('get', 'it'),
#  ('it', 'Frodo'),
#  ('Frodo', 'sat'),
#  ('sat', 'silent'),
#  ('silent', 'and'),
#  ('and', 'motionless'),
#  ('motionless', 'Fear'),
#  ('Fear', 'seemed'),
#  ('seemed', 'to'),
#  ('to', 'stretch'),
#  ('stretch', 'out'),
#  ('out', 'a'),
#  ('a', 'vast'),
#  ('vast', 'hand'),
#  ('hand', 'like'),
#  ('like', 'a'),
#  ('a', 'dark'),
#  ('dark', 'cloud'),
#  ('cloud', 'rising'),
#  ('rising', 'in'),
#  ('in', 'the'),
#  ('the', 'East'),
#  ('East', 'and'),
#  ('and', 'looming'),
#  ('looming', 'up'),
#  ('up', 'to'),
#  ('to', 'engulf'),
#  ('engulf', 'him'),
#  ('him', 'This'),
#  ('This', 'ring'),
#  ('ring', 'he'),
#  ('he', 'stammered'),
#  ('stammered', 'How'),
#  ('How', 'how'),
#  ('how', 'on'),
#  ('on', 'earth'),
#  ('earth', 'did'),
#  ('did', 'it'),
#  ('it', 'come'),
#  ('come', 'to'),
#  ('to', 'me')]

# %%
# And trigrams
list(trigrams(lotr_quote_tokenized))
# Out:
# [('I', 'can', 'not'),
#  ('can', 'not', 'read'),
#  ('not', 'read', 'the'),
#  ('read', 'the', 'fiery'),
#  ('the', 'fiery', 'letters'),
#  ('fiery', 'letters', 'said'),
#  ('letters', 'said', 'Frodo'),
#  ('said', 'Frodo', 'in'),
#  ('Frodo', 'in', 'a'),
#  ('in', 'a', 'quavering'),
#  ('a', 'quavering', 'voice'),
#  ('quavering', 'voice', 'No'),
#  ('voice', 'No', 'said'),
#  ('No', 'said', 'Gandalf'),
#  ('said', 'Gandalf', 'but'),
#  ('Gandalf', 'but', 'I'),
#  ('but', 'I', 'can'),
#  ('I', 'can', 'The'),
#  ('can', 'The', 'letters'),
#  ('The', 'letters', 'are'),
#  ('letters', 'are', 'Elvish'),
#  ('are', 'Elvish', 'of'),
#  ('Elvish', 'of', 'an'),
#  ('of', 'an', 'ancient'),
#  ('an', 'ancient', 'mode'),
#  ('ancient', 'mode', 'but'),
#  ('mode', 'but', 'the'),
#  ('but', 'the', 'language'),
#  ('the', 'language', 'is'),
#  ('language', 'is', 'that'),
#  ('is', 'that', 'of'),
#  ('that', 'of', 'Mordor'),
#  ('of', 'Mordor', 'which'),
#  ('Mordor', 'which', 'I'),
#  ('which', 'I', 'will'),
#  ('I', 'will', 'not'),
#  ('will', 'not', 'utter'),
#  ('not', 'utter', 'here'),
#  ('utter', 'here', 'But'),
#  ('here', 'But', 'this'),
#  ('But', 'this', 'in'),
#  ('this', 'in', 'the'),
#  ('in', 'the', 'Common'),
#  ('the', 'Common', 'Tongue'),
#  ('Common', 'Tongue', 'is'),
#  ('Tongue', 'is', 'what'),
#  ('is', 'what', 'is'),
#  ('what', 'is', 'said'),
#  ('is', 'said', 'close'),
#  ('said', 'close', 'enough'),
#  ('close', 'enough', 'One'),
#  ('enough', 'One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('Ring', 'to', 'rule'),
#  ('to', 'rule', 'them'),
#  ('rule', 'them', 'all'),
#  ('them', 'all', 'One'),
#  ('all', 'One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('Ring', 'to', 'find'),
#  ('to', 'find', 'them'),
#  ('find', 'them', 'One'),
#  ('them', 'One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('Ring', 'to', 'bring'),
#  ('to', 'bring', 'them'),
#  ('bring', 'them', 'all'),
#  ('them', 'all', 'and'),
#  ('all', 'and', 'in'),
#  ('and', 'in', 'the'),
#  ('in', 'the', 'darkness'),
#  ('the', 'darkness', 'bind'),
#  ('darkness', 'bind', 'them'),
#  ('bind', 'them', 'It'),
#  ('them', 'It', 'is'),
#  ('It', 'is', 'only'),
#  ('is', 'only', 'two'),
#  ('only', 'two', 'lines'),
#  ('two', 'lines', 'of'),
#  ('lines', 'of', 'a'),
#  ('of', 'a', 'verse'),
#  ('a', 'verse', 'long'),
#  ('verse', 'long', 'known'),
#  ('long', 'known', 'in'),
#  ('known', 'in', 'Elvenlore'),
#  ('in', 'Elvenlore', 'Three'),
#  ('Elvenlore', 'Three', 'Rings'),
#  ('Three', 'Rings', 'for'),
#  ('Rings', 'for', 'the'),
#  ('for', 'the', 'Elvenkings'),
#  ('the', 'Elvenkings', 'under'),
#  ('Elvenkings', 'under', 'the'),
#  ('under', 'the', 'sky'),
#  ('the', 'sky', 'Seven'),
#  ('sky', 'Seven', 'for'),
#  ('Seven', 'for', 'the'),
#  ('for', 'the', 'Dwarflords'),
#  ('the', 'Dwarflords', 'in'),
#  ('Dwarflords', 'in', 'their'),
#  ('in', 'their', 'halls'),
#  ('their', 'halls', 'of'),
#  ('halls', 'of', 'stone'),
#  ('of', 'stone', 'Nine'),
#  ('stone', 'Nine', 'for'),
#  ('Nine', 'for', 'Mortal'),
#  ('for', 'Mortal', 'Men'),
#  ('Mortal', 'Men', 'doomed'),
#  ('Men', 'doomed', 'to'),
#  ('doomed', 'to', 'die'),
#  ('to', 'die', 'One'),
#  ('die', 'One', 'for'),
#  ('One', 'for', 'the'),
#  ('for', 'the', 'Dark'),
#  ('the', 'Dark', 'Lord'),
#  ('Dark', 'Lord', 'on'),
#  ('Lord', 'on', 'his'),
#  ('on', 'his', 'dark'),
#  ('his', 'dark', 'throne'),
#  ('dark', 'throne', 'In'),
#  ('throne', 'In', 'the'),
#  ('In', 'the', 'Land'),
#  ('the', 'Land', 'of'),
#  ('Land', 'of', 'Mordor'),
#  ('of', 'Mordor', 'where'),
#  ('Mordor', 'where', 'the'),
#  ('where', 'the', 'Shadows'),
#  ('the', 'Shadows', 'lie'),
#  ('Shadows', 'lie', 'One'),
#  ('lie', 'One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('Ring', 'to', 'rule'),
#  ('to', 'rule', 'them'),
#  ('rule', 'them', 'all'),
#  ('them', 'all', 'One'),
#  ('all', 'One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('Ring', 'to', 'find'),
#  ('to', 'find', 'them'),
#  ('find', 'them', 'One'),
#  ('them', 'One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('Ring', 'to', 'bring'),
#  ('to', 'bring', 'them'),
#  ('bring', 'them', 'all'),
#  ('them', 'all', 'and'),
#  ('all', 'and', 'in'),
#  ('and', 'in', 'the'),
#  ('in', 'the', 'darkness'),
#  ('the', 'darkness', 'bind'),
#  ('darkness', 'bind', 'them'),
#  ('bind', 'them', 'In'),
#  ('them', 'In', 'the'),
#  ('In', 'the', 'Land'),
#  ('the', 'Land', 'of'),
#  ('Land', 'of', 'Mordor'),
#  ('of', 'Mordor', 'where'),
#  ('Mordor', 'where', 'the'),
#  ('where', 'the', 'Shadows'),
#  ('the', 'Shadows', 'lie'),
#  ('Shadows', 'lie', 'He'),
#  ('lie', 'He', 'paused'),
#  ('He', 'paused', 'and'),
#  ('paused', 'and', 'then'),
#  ('and', 'then', 'said'),
#  ('then', 'said', 'slowly'),
#  ('said', 'slowly', 'in'),
#  ('slowly', 'in', 'a'),
#  ('in', 'a', 'deep'),
#  ('a', 'deep', 'voice'),
#  ('deep', 'voice', 'This'),
#  ('voice', 'This', 'is'),
#  ('This', 'is', 'the'),
#  ('is', 'the', 'Masterring'),
#  ('the', 'Masterring', 'the'),
#  ('Masterring', 'the', 'One'),
#  ('the', 'One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('Ring', 'to', 'rule'),
#  ('to', 'rule', 'them'),
#  ('rule', 'them', 'all'),
#  ('them', 'all', 'This'),
#  ('all', 'This', 'is'),
#  ('This', 'is', 'the'),
#  ('is', 'the', 'One'),
#  ('the', 'One', 'Ring'),
#  ('One', 'Ring', 'that'),
#  ('Ring', 'that', 'he'),
#  ('that', 'he', 'lost'),
#  ('he', 'lost', 'many'),
#  ('lost', 'many', 'ages'),
#  ('many', 'ages', 'ago'),
#  ('ages', 'ago', 'to'),
#  ('ago', 'to', 'the'),
#  ('to', 'the', 'great'),
#  ('the', 'great', 'weakening'),
#  ('great', 'weakening', 'the'),
#  ('weakening', 'the', 'shadow'),
#  ('the', 'shadow', 'of'),
#  ('shadow', 'of', 'the'),
#  ('of', 'the', 'past'),
#  ('the', 'past', '67'),
#  ('past', '67', 'of'),
#  ('67', 'of', 'his'),
#  ('of', 'his', 'power'),
#  ('his', 'power', 'He'),
#  ('power', 'He', 'greatly'),
#  ('He', 'greatly', 'desires'),
#  ('greatly', 'desires', 'it'),
#  ('desires', 'it', '–'),
#  ('it', '–', 'but'),
#  ('–', 'but', 'he'),
#  ('but', 'he', 'must'),
#  ('he', 'must', 'not'),
#  ('must', 'not', 'get'),
#  ('not', 'get', 'it'),
#  ('get', 'it', 'Frodo'),
#  ('it', 'Frodo', 'sat'),
#  ('Frodo', 'sat', 'silent'),
#  ('sat', 'silent', 'and'),
#  ('silent', 'and', 'motionless'),
#  ('and', 'motionless', 'Fear'),
#  ('motionless', 'Fear', 'seemed'),
#  ('Fear', 'seemed', 'to'),
#  ('seemed', 'to', 'stretch'),
#  ('to', 'stretch', 'out'),
#  ('stretch', 'out', 'a'),
#  ('out', 'a', 'vast'),
#  ('a', 'vast', 'hand'),
#  ('vast', 'hand', 'like'),
#  ('hand', 'like', 'a'),
#  ('like', 'a', 'dark'),
#  ('a', 'dark', 'cloud'),
#  ('dark', 'cloud', 'rising'),
#  ('cloud', 'rising', 'in'),
#  ('rising', 'in', 'the'),
#  ('in', 'the', 'East'),
#  ('the', 'East', 'and'),
#  ('East', 'and', 'looming'),
#  ('and', 'looming', 'up'),
#  ('looming', 'up', 'to'),
#  ('up', 'to', 'engulf'),
#  ('to', 'engulf', 'him'),
#  ('engulf', 'him', 'This'),
#  ('him', 'This', 'ring'),
#  ('This', 'ring', 'he'),
#  ('ring', 'he', 'stammered'),
#  ('he', 'stammered', 'How'),
#  ('stammered', 'How', 'how'),
#  ('How', 'how', 'on'),
#  ('how', 'on', 'earth'),
#  ('on', 'earth', 'did'),
#  ('earth', 'did', 'it'),
#  ('did', 'it', 'come'),
#  ('it', 'come', 'to'),
#  ('come', 'to', 'me')]

# %%
# We can also check everygram - for example, from 2 to 6 grams!
list(everygrams(lotr_quote_tokenized, 2, 6))
# Out:
# [('I', 'can'),
#  ('I', 'can', 'not'),
#  ('I', 'can', 'not', 'read'),
#  ('I', 'can', 'not', 'read', 'the'),
#  ('I', 'can', 'not', 'read', 'the', 'fiery'),
#  ('can', 'not'),
#  ('can', 'not', 'read'),
#  ('can', 'not', 'read', 'the'),
#  ('can', 'not', 'read', 'the', 'fiery'),
#  ('can', 'not', 'read', 'the', 'fiery', 'letters'),
#  ('not', 'read'),
#  ('not', 'read', 'the'),
#  ('not', 'read', 'the', 'fiery'),
#  ('not', 'read', 'the', 'fiery', 'letters'),
#  ('not', 'read', 'the', 'fiery', 'letters', 'said'),
#  ('read', 'the'),
#  ('read', 'the', 'fiery'),
#  ('read', 'the', 'fiery', 'letters'),
#  ('read', 'the', 'fiery', 'letters', 'said'),
#  ('read', 'the', 'fiery', 'letters', 'said', 'Frodo'),
#  ('the', 'fiery'),
#  ('the', 'fiery', 'letters'),
#  ('the', 'fiery', 'letters', 'said'),
#  ('the', 'fiery', 'letters', 'said', 'Frodo'),
#  ('the', 'fiery', 'letters', 'said', 'Frodo', 'in'),
#  ('fiery', 'letters'),
#  ('fiery', 'letters', 'said'),
#  ('fiery', 'letters', 'said', 'Frodo'),
#  ('fiery', 'letters', 'said', 'Frodo', 'in'),
#  ('fiery', 'letters', 'said', 'Frodo', 'in', 'a'),
#  ('letters', 'said'),
#  ('letters', 'said', 'Frodo'),
#  ('letters', 'said', 'Frodo', 'in'),
#  ('letters', 'said', 'Frodo', 'in', 'a'),
#  ('letters', 'said', 'Frodo', 'in', 'a', 'quavering'),
#  ('said', 'Frodo'),
#  ('said', 'Frodo', 'in'),
#  ('said', 'Frodo', 'in', 'a'),
#  ('said', 'Frodo', 'in', 'a', 'quavering'),
#  ('said', 'Frodo', 'in', 'a', 'quavering', 'voice'),
#  ('Frodo', 'in'),
#  ('Frodo', 'in', 'a'),
#  ('Frodo', 'in', 'a', 'quavering'),
#  ('Frodo', 'in', 'a', 'quavering', 'voice'),
#  ('Frodo', 'in', 'a', 'quavering', 'voice', 'No'),
#  ('in', 'a'),
#  ('in', 'a', 'quavering'),
#  ('in', 'a', 'quavering', 'voice'),
#  ('in', 'a', 'quavering', 'voice', 'No'),
#  ('in', 'a', 'quavering', 'voice', 'No', 'said'),
#  ('a', 'quavering'),
#  ('a', 'quavering', 'voice'),
#  ('a', 'quavering', 'voice', 'No'),
#  ('a', 'quavering', 'voice', 'No', 'said'),
#  ('a', 'quavering', 'voice', 'No', 'said', 'Gandalf'),
#  ('quavering', 'voice'),
#  ('quavering', 'voice', 'No'),
#  ('quavering', 'voice', 'No', 'said'),
#  ('quavering', 'voice', 'No', 'said', 'Gandalf'),
#  ('quavering', 'voice', 'No', 'said', 'Gandalf', 'but'),
#  ('voice', 'No'),
#  ('voice', 'No', 'said'),
#  ('voice', 'No', 'said', 'Gandalf'),
#  ('voice', 'No', 'said', 'Gandalf', 'but'),
#  ('voice', 'No', 'said', 'Gandalf', 'but', 'I'),
#  ('No', 'said'),
#  ('No', 'said', 'Gandalf'),
#  ('No', 'said', 'Gandalf', 'but'),
#  ('No', 'said', 'Gandalf', 'but', 'I'),
#  ('No', 'said', 'Gandalf', 'but', 'I', 'can'),
#  ('said', 'Gandalf'),
#  ('said', 'Gandalf', 'but'),
#  ('said', 'Gandalf', 'but', 'I'),
#  ('said', 'Gandalf', 'but', 'I', 'can'),
#  ('said', 'Gandalf', 'but', 'I', 'can', 'The'),
#  ('Gandalf', 'but'),
#  ('Gandalf', 'but', 'I'),
#  ('Gandalf', 'but', 'I', 'can'),
#  ('Gandalf', 'but', 'I', 'can', 'The'),
#  ('Gandalf', 'but', 'I', 'can', 'The', 'letters'),
#  ('but', 'I'),
#  ('but', 'I', 'can'),
#  ('but', 'I', 'can', 'The'),
#  ('but', 'I', 'can', 'The', 'letters'),
#  ('but', 'I', 'can', 'The', 'letters', 'are'),
#  ('I', 'can'),
#  ('I', 'can', 'The'),
#  ('I', 'can', 'The', 'letters'),
#  ('I', 'can', 'The', 'letters', 'are'),
#  ('I', 'can', 'The', 'letters', 'are', 'Elvish'),
#  ('can', 'The'),
#  ('can', 'The', 'letters'),
#  ('can', 'The', 'letters', 'are'),
#  ('can', 'The', 'letters', 'are', 'Elvish'),
#  ('can', 'The', 'letters', 'are', 'Elvish', 'of'),
#  ('The', 'letters'),
#  ('The', 'letters', 'are'),
#  ('The', 'letters', 'are', 'Elvish'),
#  ('The', 'letters', 'are', 'Elvish', 'of'),
#  ('The', 'letters', 'are', 'Elvish', 'of', 'an'),
#  ('letters', 'are'),
#  ('letters', 'are', 'Elvish'),
#  ('letters', 'are', 'Elvish', 'of'),
#  ('letters', 'are', 'Elvish', 'of', 'an'),
#  ('letters', 'are', 'Elvish', 'of', 'an', 'ancient'),
#  ('are', 'Elvish'),
#  ('are', 'Elvish', 'of'),
#  ('are', 'Elvish', 'of', 'an'),
#  ('are', 'Elvish', 'of', 'an', 'ancient'),
#  ('are', 'Elvish', 'of', 'an', 'ancient', 'mode'),
#  ('Elvish', 'of'),
#  ('Elvish', 'of', 'an'),
#  ('Elvish', 'of', 'an', 'ancient'),
#  ('Elvish', 'of', 'an', 'ancient', 'mode'),
#  ('Elvish', 'of', 'an', 'ancient', 'mode', 'but'),
#  ('of', 'an'),
#  ('of', 'an', 'ancient'),
#  ('of', 'an', 'ancient', 'mode'),
#  ('of', 'an', 'ancient', 'mode', 'but'),
#  ('of', 'an', 'ancient', 'mode', 'but', 'the'),
#  ('an', 'ancient'),
#  ('an', 'ancient', 'mode'),
#  ('an', 'ancient', 'mode', 'but'),
#  ('an', 'ancient', 'mode', 'but', 'the'),
#  ('an', 'ancient', 'mode', 'but', 'the', 'language'),
#  ('ancient', 'mode'),
#  ('ancient', 'mode', 'but'),
#  ('ancient', 'mode', 'but', 'the'),
#  ('ancient', 'mode', 'but', 'the', 'language'),
#  ('ancient', 'mode', 'but', 'the', 'language', 'is'),
#  ('mode', 'but'),
#  ('mode', 'but', 'the'),
#  ('mode', 'but', 'the', 'language'),
#  ('mode', 'but', 'the', 'language', 'is'),
#  ('mode', 'but', 'the', 'language', 'is', 'that'),
#  ('but', 'the'),
#  ('but', 'the', 'language'),
#  ('but', 'the', 'language', 'is'),
#  ('but', 'the', 'language', 'is', 'that'),
#  ('but', 'the', 'language', 'is', 'that', 'of'),
#  ('the', 'language'),
#  ('the', 'language', 'is'),
#  ('the', 'language', 'is', 'that'),
#  ('the', 'language', 'is', 'that', 'of'),
#  ('the', 'language', 'is', 'that', 'of', 'Mordor'),
#  ('language', 'is'),
#  ('language', 'is', 'that'),
#  ('language', 'is', 'that', 'of'),
#  ('language', 'is', 'that', 'of', 'Mordor'),
#  ('language', 'is', 'that', 'of', 'Mordor', 'which'),
#  ('is', 'that'),
#  ('is', 'that', 'of'),
#  ('is', 'that', 'of', 'Mordor'),
#  ('is', 'that', 'of', 'Mordor', 'which'),
#  ('is', 'that', 'of', 'Mordor', 'which', 'I'),
#  ('that', 'of'),
#  ('that', 'of', 'Mordor'),
#  ('that', 'of', 'Mordor', 'which'),
#  ('that', 'of', 'Mordor', 'which', 'I'),
#  ('that', 'of', 'Mordor', 'which', 'I', 'will'),
#  ('of', 'Mordor'),
#  ('of', 'Mordor', 'which'),
#  ('of', 'Mordor', 'which', 'I'),
#  ('of', 'Mordor', 'which', 'I', 'will'),
#  ('of', 'Mordor', 'which', 'I', 'will', 'not'),
#  ('Mordor', 'which'),
#  ('Mordor', 'which', 'I'),
#  ('Mordor', 'which', 'I', 'will'),
#  ('Mordor', 'which', 'I', 'will', 'not'),
#  ('Mordor', 'which', 'I', 'will', 'not', 'utter'),
#  ('which', 'I'),
#  ('which', 'I', 'will'),
#  ('which', 'I', 'will', 'not'),
#  ('which', 'I', 'will', 'not', 'utter'),
#  ('which', 'I', 'will', 'not', 'utter', 'here'),
#  ('I', 'will'),
#  ('I', 'will', 'not'),
#  ('I', 'will', 'not', 'utter'),
#  ('I', 'will', 'not', 'utter', 'here'),
#  ('I', 'will', 'not', 'utter', 'here', 'But'),
#  ('will', 'not'),
#  ('will', 'not', 'utter'),
#  ('will', 'not', 'utter', 'here'),
#  ('will', 'not', 'utter', 'here', 'But'),
#  ('will', 'not', 'utter', 'here', 'But', 'this'),
#  ('not', 'utter'),
#  ('not', 'utter', 'here'),
#  ('not', 'utter', 'here', 'But'),
#  ('not', 'utter', 'here', 'But', 'this'),
#  ('not', 'utter', 'here', 'But', 'this', 'in'),
#  ('utter', 'here'),
#  ('utter', 'here', 'But'),
#  ('utter', 'here', 'But', 'this'),
#  ('utter', 'here', 'But', 'this', 'in'),
#  ('utter', 'here', 'But', 'this', 'in', 'the'),
#  ('here', 'But'),
#  ('here', 'But', 'this'),
#  ('here', 'But', 'this', 'in'),
#  ('here', 'But', 'this', 'in', 'the'),
#  ('here', 'But', 'this', 'in', 'the', 'Common'),
#  ('But', 'this'),
#  ('But', 'this', 'in'),
#  ('But', 'this', 'in', 'the'),
#  ('But', 'this', 'in', 'the', 'Common'),
#  ('But', 'this', 'in', 'the', 'Common', 'Tongue'),
#  ('this', 'in'),
#  ('this', 'in', 'the'),
#  ('this', 'in', 'the', 'Common'),
#  ('this', 'in', 'the', 'Common', 'Tongue'),
#  ('this', 'in', 'the', 'Common', 'Tongue', 'is'),
#  ('in', 'the'),
#  ('in', 'the', 'Common'),
#  ('in', 'the', 'Common', 'Tongue'),
#  ('in', 'the', 'Common', 'Tongue', 'is'),
#  ('in', 'the', 'Common', 'Tongue', 'is', 'what'),
#  ('the', 'Common'),
#  ('the', 'Common', 'Tongue'),
#  ('the', 'Common', 'Tongue', 'is'),
#  ('the', 'Common', 'Tongue', 'is', 'what'),
#  ('the', 'Common', 'Tongue', 'is', 'what', 'is'),
#  ('Common', 'Tongue'),
#  ('Common', 'Tongue', 'is'),
#  ('Common', 'Tongue', 'is', 'what'),
#  ('Common', 'Tongue', 'is', 'what', 'is'),
#  ('Common', 'Tongue', 'is', 'what', 'is', 'said'),
#  ('Tongue', 'is'),
#  ('Tongue', 'is', 'what'),
#  ('Tongue', 'is', 'what', 'is'),
#  ('Tongue', 'is', 'what', 'is', 'said'),
#  ('Tongue', 'is', 'what', 'is', 'said', 'close'),
#  ('is', 'what'),
#  ('is', 'what', 'is'),
#  ('is', 'what', 'is', 'said'),
#  ('is', 'what', 'is', 'said', 'close'),
#  ('is', 'what', 'is', 'said', 'close', 'enough'),
#  ('what', 'is'),
#  ('what', 'is', 'said'),
#  ('what', 'is', 'said', 'close'),
#  ('what', 'is', 'said', 'close', 'enough'),
#  ('what', 'is', 'said', 'close', 'enough', 'One'),
#  ('is', 'said'),
#  ('is', 'said', 'close'),
#  ('is', 'said', 'close', 'enough'),
#  ('is', 'said', 'close', 'enough', 'One'),
#  ('is', 'said', 'close', 'enough', 'One', 'Ring'),
#  ('said', 'close'),
#  ('said', 'close', 'enough'),
#  ('said', 'close', 'enough', 'One'),
#  ('said', 'close', 'enough', 'One', 'Ring'),
#  ('said', 'close', 'enough', 'One', 'Ring', 'to'),
#  ('close', 'enough'),
#  ('close', 'enough', 'One'),
#  ('close', 'enough', 'One', 'Ring'),
#  ('close', 'enough', 'One', 'Ring', 'to'),
#  ('close', 'enough', 'One', 'Ring', 'to', 'rule'),
#  ('enough', 'One'),
#  ('enough', 'One', 'Ring'),
#  ('enough', 'One', 'Ring', 'to'),
#  ('enough', 'One', 'Ring', 'to', 'rule'),
#  ('enough', 'One', 'Ring', 'to', 'rule', 'them'),
#  ('One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('One', 'Ring', 'to', 'rule'),
#  ('One', 'Ring', 'to', 'rule', 'them'),
#  ('One', 'Ring', 'to', 'rule', 'them', 'all'),
#  ('Ring', 'to'),
#  ('Ring', 'to', 'rule'),
#  ('Ring', 'to', 'rule', 'them'),
#  ('Ring', 'to', 'rule', 'them', 'all'),
#  ('Ring', 'to', 'rule', 'them', 'all', 'One'),
#  ('to', 'rule'),
#  ('to', 'rule', 'them'),
#  ('to', 'rule', 'them', 'all'),
#  ('to', 'rule', 'them', 'all', 'One'),
#  ('to', 'rule', 'them', 'all', 'One', 'Ring'),
#  ('rule', 'them'),
#  ('rule', 'them', 'all'),
#  ('rule', 'them', 'all', 'One'),
#  ('rule', 'them', 'all', 'One', 'Ring'),
#  ('rule', 'them', 'all', 'One', 'Ring', 'to'),
#  ('them', 'all'),
#  ('them', 'all', 'One'),
#  ('them', 'all', 'One', 'Ring'),
#  ('them', 'all', 'One', 'Ring', 'to'),
#  ('them', 'all', 'One', 'Ring', 'to', 'find'),
#  ('all', 'One'),
#  ('all', 'One', 'Ring'),
#  ('all', 'One', 'Ring', 'to'),
#  ('all', 'One', 'Ring', 'to', 'find'),
#  ('all', 'One', 'Ring', 'to', 'find', 'them'),
#  ('One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('One', 'Ring', 'to', 'find'),
#  ('One', 'Ring', 'to', 'find', 'them'),
#  ('One', 'Ring', 'to', 'find', 'them', 'One'),
#  ('Ring', 'to'),
#  ('Ring', 'to', 'find'),
#  ('Ring', 'to', 'find', 'them'),
#  ('Ring', 'to', 'find', 'them', 'One'),
#  ('Ring', 'to', 'find', 'them', 'One', 'Ring'),
#  ('to', 'find'),
#  ('to', 'find', 'them'),
#  ('to', 'find', 'them', 'One'),
#  ('to', 'find', 'them', 'One', 'Ring'),
#  ('to', 'find', 'them', 'One', 'Ring', 'to'),
#  ('find', 'them'),
#  ('find', 'them', 'One'),
#  ('find', 'them', 'One', 'Ring'),
#  ('find', 'them', 'One', 'Ring', 'to'),
#  ('find', 'them', 'One', 'Ring', 'to', 'bring'),
#  ('them', 'One'),
#  ('them', 'One', 'Ring'),
#  ('them', 'One', 'Ring', 'to'),
#  ('them', 'One', 'Ring', 'to', 'bring'),
#  ('them', 'One', 'Ring', 'to', 'bring', 'them'),
#  ('One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('One', 'Ring', 'to', 'bring'),
#  ('One', 'Ring', 'to', 'bring', 'them'),
#  ('One', 'Ring', 'to', 'bring', 'them', 'all'),
#  ('Ring', 'to'),
#  ('Ring', 'to', 'bring'),
#  ('Ring', 'to', 'bring', 'them'),
#  ('Ring', 'to', 'bring', 'them', 'all'),
#  ('Ring', 'to', 'bring', 'them', 'all', 'and'),
#  ('to', 'bring'),
#  ('to', 'bring', 'them'),
#  ('to', 'bring', 'them', 'all'),
#  ('to', 'bring', 'them', 'all', 'and'),
#  ('to', 'bring', 'them', 'all', 'and', 'in'),
#  ('bring', 'them'),
#  ('bring', 'them', 'all'),
#  ('bring', 'them', 'all', 'and'),
#  ('bring', 'them', 'all', 'and', 'in'),
#  ('bring', 'them', 'all', 'and', 'in', 'the'),
#  ('them', 'all'),
#  ('them', 'all', 'and'),
#  ('them', 'all', 'and', 'in'),
#  ('them', 'all', 'and', 'in', 'the'),
#  ('them', 'all', 'and', 'in', 'the', 'darkness'),
#  ('all', 'and'),
#  ('all', 'and', 'in'),
#  ('all', 'and', 'in', 'the'),
#  ('all', 'and', 'in', 'the', 'darkness'),
#  ('all', 'and', 'in', 'the', 'darkness', 'bind'),
#  ('and', 'in'),
#  ('and', 'in', 'the'),
#  ('and', 'in', 'the', 'darkness'),
#  ('and', 'in', 'the', 'darkness', 'bind'),
#  ('and', 'in', 'the', 'darkness', 'bind', 'them'),
#  ('in', 'the'),
#  ('in', 'the', 'darkness'),
#  ('in', 'the', 'darkness', 'bind'),
#  ('in', 'the', 'darkness', 'bind', 'them'),
#  ('in', 'the', 'darkness', 'bind', 'them', 'It'),
#  ('the', 'darkness'),
#  ('the', 'darkness', 'bind'),
#  ('the', 'darkness', 'bind', 'them'),
#  ('the', 'darkness', 'bind', 'them', 'It'),
#  ('the', 'darkness', 'bind', 'them', 'It', 'is'),
#  ('darkness', 'bind'),
#  ('darkness', 'bind', 'them'),
#  ('darkness', 'bind', 'them', 'It'),
#  ('darkness', 'bind', 'them', 'It', 'is'),
#  ('darkness', 'bind', 'them', 'It', 'is', 'only'),
#  ('bind', 'them'),
#  ('bind', 'them', 'It'),
#  ('bind', 'them', 'It', 'is'),
#  ('bind', 'them', 'It', 'is', 'only'),
#  ('bind', 'them', 'It', 'is', 'only', 'two'),
#  ('them', 'It'),
#  ('them', 'It', 'is'),
#  ('them', 'It', 'is', 'only'),
#  ('them', 'It', 'is', 'only', 'two'),
#  ('them', 'It', 'is', 'only', 'two', 'lines'),
#  ('It', 'is'),
#  ('It', 'is', 'only'),
#  ('It', 'is', 'only', 'two'),
#  ('It', 'is', 'only', 'two', 'lines'),
#  ('It', 'is', 'only', 'two', 'lines', 'of'),
#  ('is', 'only'),
#  ('is', 'only', 'two'),
#  ('is', 'only', 'two', 'lines'),
#  ('is', 'only', 'two', 'lines', 'of'),
#  ('is', 'only', 'two', 'lines', 'of', 'a'),
#  ('only', 'two'),
#  ('only', 'two', 'lines'),
#  ('only', 'two', 'lines', 'of'),
#  ('only', 'two', 'lines', 'of', 'a'),
#  ('only', 'two', 'lines', 'of', 'a', 'verse'),
#  ('two', 'lines'),
#  ('two', 'lines', 'of'),
#  ('two', 'lines', 'of', 'a'),
#  ('two', 'lines', 'of', 'a', 'verse'),
#  ('two', 'lines', 'of', 'a', 'verse', 'long'),
#  ('lines', 'of'),
#  ('lines', 'of', 'a'),
#  ('lines', 'of', 'a', 'verse'),
#  ('lines', 'of', 'a', 'verse', 'long'),
#  ('lines', 'of', 'a', 'verse', 'long', 'known'),
#  ('of', 'a'),
#  ('of', 'a', 'verse'),
#  ('of', 'a', 'verse', 'long'),
#  ('of', 'a', 'verse', 'long', 'known'),
#  ('of', 'a', 'verse', 'long', 'known', 'in'),
#  ('a', 'verse'),
#  ('a', 'verse', 'long'),
#  ('a', 'verse', 'long', 'known'),
#  ('a', 'verse', 'long', 'known', 'in'),
#  ('a', 'verse', 'long', 'known', 'in', 'Elvenlore'),
#  ('verse', 'long'),
#  ('verse', 'long', 'known'),
#  ('verse', 'long', 'known', 'in'),
#  ('verse', 'long', 'known', 'in', 'Elvenlore'),
#  ('verse', 'long', 'known', 'in', 'Elvenlore', 'Three'),
#  ('long', 'known'),
#  ('long', 'known', 'in'),
#  ('long', 'known', 'in', 'Elvenlore'),
#  ('long', 'known', 'in', 'Elvenlore', 'Three'),
#  ('long', 'known', 'in', 'Elvenlore', 'Three', 'Rings'),
#  ('known', 'in'),
#  ('known', 'in', 'Elvenlore'),
#  ('known', 'in', 'Elvenlore', 'Three'),
#  ('known', 'in', 'Elvenlore', 'Three', 'Rings'),
#  ('known', 'in', 'Elvenlore', 'Three', 'Rings', 'for'),
#  ('in', 'Elvenlore'),
#  ('in', 'Elvenlore', 'Three'),
#  ('in', 'Elvenlore', 'Three', 'Rings'),
#  ('in', 'Elvenlore', 'Three', 'Rings', 'for'),
#  ('in', 'Elvenlore', 'Three', 'Rings', 'for', 'the'),
#  ('Elvenlore', 'Three'),
#  ('Elvenlore', 'Three', 'Rings'),
#  ('Elvenlore', 'Three', 'Rings', 'for'),
#  ('Elvenlore', 'Three', 'Rings', 'for', 'the'),
#  ('Elvenlore', 'Three', 'Rings', 'for', 'the', 'Elvenkings'),
#  ('Three', 'Rings'),
#  ('Three', 'Rings', 'for'),
#  ('Three', 'Rings', 'for', 'the'),
#  ('Three', 'Rings', 'for', 'the', 'Elvenkings'),
#  ('Three', 'Rings', 'for', 'the', 'Elvenkings', 'under'),
#  ('Rings', 'for'),
#  ('Rings', 'for', 'the'),
#  ('Rings', 'for', 'the', 'Elvenkings'),
#  ('Rings', 'for', 'the', 'Elvenkings', 'under'),
#  ('Rings', 'for', 'the', 'Elvenkings', 'under', 'the'),
#  ('for', 'the'),
#  ('for', 'the', 'Elvenkings'),
#  ('for', 'the', 'Elvenkings', 'under'),
#  ('for', 'the', 'Elvenkings', 'under', 'the'),
#  ('for', 'the', 'Elvenkings', 'under', 'the', 'sky'),
#  ('the', 'Elvenkings'),
#  ('the', 'Elvenkings', 'under'),
#  ('the', 'Elvenkings', 'under', 'the'),
#  ('the', 'Elvenkings', 'under', 'the', 'sky'),
#  ('the', 'Elvenkings', 'under', 'the', 'sky', 'Seven'),
#  ('Elvenkings', 'under'),
#  ('Elvenkings', 'under', 'the'),
#  ('Elvenkings', 'under', 'the', 'sky'),
#  ('Elvenkings', 'under', 'the', 'sky', 'Seven'),
#  ('Elvenkings', 'under', 'the', 'sky', 'Seven', 'for'),
#  ('under', 'the'),
#  ('under', 'the', 'sky'),
#  ('under', 'the', 'sky', 'Seven'),
#  ('under', 'the', 'sky', 'Seven', 'for'),
#  ('under', 'the', 'sky', 'Seven', 'for', 'the'),
#  ('the', 'sky'),
#  ('the', 'sky', 'Seven'),
#  ('the', 'sky', 'Seven', 'for'),
#  ('the', 'sky', 'Seven', 'for', 'the'),
#  ('the', 'sky', 'Seven', 'for', 'the', 'Dwarflords'),
#  ('sky', 'Seven'),
#  ('sky', 'Seven', 'for'),
#  ('sky', 'Seven', 'for', 'the'),
#  ('sky', 'Seven', 'for', 'the', 'Dwarflords'),
#  ('sky', 'Seven', 'for', 'the', 'Dwarflords', 'in'),
#  ('Seven', 'for'),
#  ('Seven', 'for', 'the'),
#  ('Seven', 'for', 'the', 'Dwarflords'),
#  ('Seven', 'for', 'the', 'Dwarflords', 'in'),
#  ('Seven', 'for', 'the', 'Dwarflords', 'in', 'their'),
#  ('for', 'the'),
#  ('for', 'the', 'Dwarflords'),
#  ('for', 'the', 'Dwarflords', 'in'),
#  ('for', 'the', 'Dwarflords', 'in', 'their'),
#  ('for', 'the', 'Dwarflords', 'in', 'their', 'halls'),
#  ('the', 'Dwarflords'),
#  ('the', 'Dwarflords', 'in'),
#  ('the', 'Dwarflords', 'in', 'their'),
#  ('the', 'Dwarflords', 'in', 'their', 'halls'),
#  ('the', 'Dwarflords', 'in', 'their', 'halls', 'of'),
#  ('Dwarflords', 'in'),
#  ('Dwarflords', 'in', 'their'),
#  ('Dwarflords', 'in', 'their', 'halls'),
#  ('Dwarflords', 'in', 'their', 'halls', 'of'),
#  ('Dwarflords', 'in', 'their', 'halls', 'of', 'stone'),
#  ('in', 'their'),
#  ('in', 'their', 'halls'),
#  ('in', 'their', 'halls', 'of'),
#  ('in', 'their', 'halls', 'of', 'stone'),
#  ('in', 'their', 'halls', 'of', 'stone', 'Nine'),
#  ('their', 'halls'),
#  ('their', 'halls', 'of'),
#  ('their', 'halls', 'of', 'stone'),
#  ('their', 'halls', 'of', 'stone', 'Nine'),
#  ('their', 'halls', 'of', 'stone', 'Nine', 'for'),
#  ('halls', 'of'),
#  ('halls', 'of', 'stone'),
#  ('halls', 'of', 'stone', 'Nine'),
#  ('halls', 'of', 'stone', 'Nine', 'for'),
#  ('halls', 'of', 'stone', 'Nine', 'for', 'Mortal'),
#  ('of', 'stone'),
#  ('of', 'stone', 'Nine'),
#  ('of', 'stone', 'Nine', 'for'),
#  ('of', 'stone', 'Nine', 'for', 'Mortal'),
#  ('of', 'stone', 'Nine', 'for', 'Mortal', 'Men'),
#  ('stone', 'Nine'),
#  ('stone', 'Nine', 'for'),
#  ('stone', 'Nine', 'for', 'Mortal'),
#  ('stone', 'Nine', 'for', 'Mortal', 'Men'),
#  ('stone', 'Nine', 'for', 'Mortal', 'Men', 'doomed'),
#  ('Nine', 'for'),
#  ('Nine', 'for', 'Mortal'),
#  ('Nine', 'for', 'Mortal', 'Men'),
#  ('Nine', 'for', 'Mortal', 'Men', 'doomed'),
#  ('Nine', 'for', 'Mortal', 'Men', 'doomed', 'to'),
#  ('for', 'Mortal'),
#  ('for', 'Mortal', 'Men'),
#  ('for', 'Mortal', 'Men', 'doomed'),
#  ('for', 'Mortal', 'Men', 'doomed', 'to'),
#  ('for', 'Mortal', 'Men', 'doomed', 'to', 'die'),
#  ('Mortal', 'Men'),
#  ('Mortal', 'Men', 'doomed'),
#  ('Mortal', 'Men', 'doomed', 'to'),
#  ('Mortal', 'Men', 'doomed', 'to', 'die'),
#  ('Mortal', 'Men', 'doomed', 'to', 'die', 'One'),
#  ('Men', 'doomed'),
#  ('Men', 'doomed', 'to'),
#  ('Men', 'doomed', 'to', 'die'),
#  ('Men', 'doomed', 'to', 'die', 'One'),
#  ('Men', 'doomed', 'to', 'die', 'One', 'for'),
#  ('doomed', 'to'),
#  ('doomed', 'to', 'die'),
#  ('doomed', 'to', 'die', 'One'),
#  ('doomed', 'to', 'die', 'One', 'for'),
#  ('doomed', 'to', 'die', 'One', 'for', 'the'),
#  ('to', 'die'),
#  ('to', 'die', 'One'),
#  ('to', 'die', 'One', 'for'),
#  ('to', 'die', 'One', 'for', 'the'),
#  ('to', 'die', 'One', 'for', 'the', 'Dark'),
#  ('die', 'One'),
#  ('die', 'One', 'for'),
#  ('die', 'One', 'for', 'the'),
#  ('die', 'One', 'for', 'the', 'Dark'),
#  ('die', 'One', 'for', 'the', 'Dark', 'Lord'),
#  ('One', 'for'),
#  ('One', 'for', 'the'),
#  ('One', 'for', 'the', 'Dark'),
#  ('One', 'for', 'the', 'Dark', 'Lord'),
#  ('One', 'for', 'the', 'Dark', 'Lord', 'on'),
#  ('for', 'the'),
#  ('for', 'the', 'Dark'),
#  ('for', 'the', 'Dark', 'Lord'),
#  ('for', 'the', 'Dark', 'Lord', 'on'),
#  ('for', 'the', 'Dark', 'Lord', 'on', 'his'),
#  ('the', 'Dark'),
#  ('the', 'Dark', 'Lord'),
#  ('the', 'Dark', 'Lord', 'on'),
#  ('the', 'Dark', 'Lord', 'on', 'his'),
#  ('the', 'Dark', 'Lord', 'on', 'his', 'dark'),
#  ('Dark', 'Lord'),
#  ('Dark', 'Lord', 'on'),
#  ('Dark', 'Lord', 'on', 'his'),
#  ('Dark', 'Lord', 'on', 'his', 'dark'),
#  ('Dark', 'Lord', 'on', 'his', 'dark', 'throne'),
#  ('Lord', 'on'),
#  ('Lord', 'on', 'his'),
#  ('Lord', 'on', 'his', 'dark'),
#  ('Lord', 'on', 'his', 'dark', 'throne'),
#  ('Lord', 'on', 'his', 'dark', 'throne', 'In'),
#  ('on', 'his'),
#  ('on', 'his', 'dark'),
#  ('on', 'his', 'dark', 'throne'),
#  ('on', 'his', 'dark', 'throne', 'In'),
#  ('on', 'his', 'dark', 'throne', 'In', 'the'),
#  ('his', 'dark'),
#  ('his', 'dark', 'throne'),
#  ('his', 'dark', 'throne', 'In'),
#  ('his', 'dark', 'throne', 'In', 'the'),
#  ('his', 'dark', 'throne', 'In', 'the', 'Land'),
#  ('dark', 'throne'),
#  ('dark', 'throne', 'In'),
#  ('dark', 'throne', 'In', 'the'),
#  ('dark', 'throne', 'In', 'the', 'Land'),
#  ('dark', 'throne', 'In', 'the', 'Land', 'of'),
#  ('throne', 'In'),
#  ('throne', 'In', 'the'),
#  ('throne', 'In', 'the', 'Land'),
#  ('throne', 'In', 'the', 'Land', 'of'),
#  ('throne', 'In', 'the', 'Land', 'of', 'Mordor'),
#  ('In', 'the'),
#  ('In', 'the', 'Land'),
#  ('In', 'the', 'Land', 'of'),
#  ('In', 'the', 'Land', 'of', 'Mordor'),
#  ('In', 'the', 'Land', 'of', 'Mordor', 'where'),
#  ('the', 'Land'),
#  ('the', 'Land', 'of'),
#  ('the', 'Land', 'of', 'Mordor'),
#  ('the', 'Land', 'of', 'Mordor', 'where'),
#  ('the', 'Land', 'of', 'Mordor', 'where', 'the'),
#  ('Land', 'of'),
#  ('Land', 'of', 'Mordor'),
#  ('Land', 'of', 'Mordor', 'where'),
#  ('Land', 'of', 'Mordor', 'where', 'the'),
#  ('Land', 'of', 'Mordor', 'where', 'the', 'Shadows'),
#  ('of', 'Mordor'),
#  ('of', 'Mordor', 'where'),
#  ('of', 'Mordor', 'where', 'the'),
#  ('of', 'Mordor', 'where', 'the', 'Shadows'),
#  ('of', 'Mordor', 'where', 'the', 'Shadows', 'lie'),
#  ('Mordor', 'where'),
#  ('Mordor', 'where', 'the'),
#  ('Mordor', 'where', 'the', 'Shadows'),
#  ('Mordor', 'where', 'the', 'Shadows', 'lie'),
#  ('Mordor', 'where', 'the', 'Shadows', 'lie', 'One'),
#  ('where', 'the'),
#  ('where', 'the', 'Shadows'),
#  ('where', 'the', 'Shadows', 'lie'),
#  ('where', 'the', 'Shadows', 'lie', 'One'),
#  ('where', 'the', 'Shadows', 'lie', 'One', 'Ring'),
#  ('the', 'Shadows'),
#  ('the', 'Shadows', 'lie'),
#  ('the', 'Shadows', 'lie', 'One'),
#  ('the', 'Shadows', 'lie', 'One', 'Ring'),
#  ('the', 'Shadows', 'lie', 'One', 'Ring', 'to'),
#  ('Shadows', 'lie'),
#  ('Shadows', 'lie', 'One'),
#  ('Shadows', 'lie', 'One', 'Ring'),
#  ('Shadows', 'lie', 'One', 'Ring', 'to'),
#  ('Shadows', 'lie', 'One', 'Ring', 'to', 'rule'),
#  ('lie', 'One'),
#  ('lie', 'One', 'Ring'),
#  ('lie', 'One', 'Ring', 'to'),
#  ('lie', 'One', 'Ring', 'to', 'rule'),
#  ('lie', 'One', 'Ring', 'to', 'rule', 'them'),
#  ('One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('One', 'Ring', 'to', 'rule'),
#  ('One', 'Ring', 'to', 'rule', 'them'),
#  ('One', 'Ring', 'to', 'rule', 'them', 'all'),
#  ('Ring', 'to'),
#  ('Ring', 'to', 'rule'),
#  ('Ring', 'to', 'rule', 'them'),
#  ('Ring', 'to', 'rule', 'them', 'all'),
#  ('Ring', 'to', 'rule', 'them', 'all', 'One'),
#  ('to', 'rule'),
#  ('to', 'rule', 'them'),
#  ('to', 'rule', 'them', 'all'),
#  ('to', 'rule', 'them', 'all', 'One'),
#  ('to', 'rule', 'them', 'all', 'One', 'Ring'),
#  ('rule', 'them'),
#  ('rule', 'them', 'all'),
#  ('rule', 'them', 'all', 'One'),
#  ('rule', 'them', 'all', 'One', 'Ring'),
#  ('rule', 'them', 'all', 'One', 'Ring', 'to'),
#  ('them', 'all'),
#  ('them', 'all', 'One'),
#  ('them', 'all', 'One', 'Ring'),
#  ('them', 'all', 'One', 'Ring', 'to'),
#  ('them', 'all', 'One', 'Ring', 'to', 'find'),
#  ('all', 'One'),
#  ('all', 'One', 'Ring'),
#  ('all', 'One', 'Ring', 'to'),
#  ('all', 'One', 'Ring', 'to', 'find'),
#  ('all', 'One', 'Ring', 'to', 'find', 'them'),
#  ('One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('One', 'Ring', 'to', 'find'),
#  ('One', 'Ring', 'to', 'find', 'them'),
#  ('One', 'Ring', 'to', 'find', 'them', 'One'),
#  ('Ring', 'to'),
#  ('Ring', 'to', 'find'),
#  ('Ring', 'to', 'find', 'them'),
#  ('Ring', 'to', 'find', 'them', 'One'),
#  ('Ring', 'to', 'find', 'them', 'One', 'Ring'),
#  ('to', 'find'),
#  ('to', 'find', 'them'),
#  ('to', 'find', 'them', 'One'),
#  ('to', 'find', 'them', 'One', 'Ring'),
#  ('to', 'find', 'them', 'One', 'Ring', 'to'),
#  ('find', 'them'),
#  ('find', 'them', 'One'),
#  ('find', 'them', 'One', 'Ring'),
#  ('find', 'them', 'One', 'Ring', 'to'),
#  ('find', 'them', 'One', 'Ring', 'to', 'bring'),
#  ('them', 'One'),
#  ('them', 'One', 'Ring'),
#  ('them', 'One', 'Ring', 'to'),
#  ('them', 'One', 'Ring', 'to', 'bring'),
#  ('them', 'One', 'Ring', 'to', 'bring', 'them'),
#  ('One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('One', 'Ring', 'to', 'bring'),
#  ('One', 'Ring', 'to', 'bring', 'them'),
#  ('One', 'Ring', 'to', 'bring', 'them', 'all'),
#  ('Ring', 'to'),
#  ('Ring', 'to', 'bring'),
#  ('Ring', 'to', 'bring', 'them'),
#  ('Ring', 'to', 'bring', 'them', 'all'),
#  ('Ring', 'to', 'bring', 'them', 'all', 'and'),
#  ('to', 'bring'),
#  ('to', 'bring', 'them'),
#  ('to', 'bring', 'them', 'all'),
#  ('to', 'bring', 'them', 'all', 'and'),
#  ('to', 'bring', 'them', 'all', 'and', 'in'),
#  ('bring', 'them'),
#  ('bring', 'them', 'all'),
#  ('bring', 'them', 'all', 'and'),
#  ('bring', 'them', 'all', 'and', 'in'),
#  ('bring', 'them', 'all', 'and', 'in', 'the'),
#  ('them', 'all'),
#  ('them', 'all', 'and'),
#  ('them', 'all', 'and', 'in'),
#  ('them', 'all', 'and', 'in', 'the'),
#  ('them', 'all', 'and', 'in', 'the', 'darkness'),
#  ('all', 'and'),
#  ('all', 'and', 'in'),
#  ('all', 'and', 'in', 'the'),
#  ('all', 'and', 'in', 'the', 'darkness'),
#  ('all', 'and', 'in', 'the', 'darkness', 'bind'),
#  ('and', 'in'),
#  ('and', 'in', 'the'),
#  ('and', 'in', 'the', 'darkness'),
#  ('and', 'in', 'the', 'darkness', 'bind'),
#  ('and', 'in', 'the', 'darkness', 'bind', 'them'),
#  ('in', 'the'),
#  ('in', 'the', 'darkness'),
#  ('in', 'the', 'darkness', 'bind'),
#  ('in', 'the', 'darkness', 'bind', 'them'),
#  ('in', 'the', 'darkness', 'bind', 'them', 'In'),
#  ('the', 'darkness'),
#  ('the', 'darkness', 'bind'),
#  ('the', 'darkness', 'bind', 'them'),
#  ('the', 'darkness', 'bind', 'them', 'In'),
#  ('the', 'darkness', 'bind', 'them', 'In', 'the'),
#  ('darkness', 'bind'),
#  ('darkness', 'bind', 'them'),
#  ('darkness', 'bind', 'them', 'In'),
#  ('darkness', 'bind', 'them', 'In', 'the'),
#  ('darkness', 'bind', 'them', 'In', 'the', 'Land'),
#  ('bind', 'them'),
#  ('bind', 'them', 'In'),
#  ('bind', 'them', 'In', 'the'),
#  ('bind', 'them', 'In', 'the', 'Land'),
#  ('bind', 'them', 'In', 'the', 'Land', 'of'),
#  ('them', 'In'),
#  ('them', 'In', 'the'),
#  ('them', 'In', 'the', 'Land'),
#  ('them', 'In', 'the', 'Land', 'of'),
#  ('them', 'In', 'the', 'Land', 'of', 'Mordor'),
#  ('In', 'the'),
#  ('In', 'the', 'Land'),
#  ('In', 'the', 'Land', 'of'),
#  ('In', 'the', 'Land', 'of', 'Mordor'),
#  ('In', 'the', 'Land', 'of', 'Mordor', 'where'),
#  ('the', 'Land'),
#  ('the', 'Land', 'of'),
#  ('the', 'Land', 'of', 'Mordor'),
#  ('the', 'Land', 'of', 'Mordor', 'where'),
#  ('the', 'Land', 'of', 'Mordor', 'where', 'the'),
#  ('Land', 'of'),
#  ('Land', 'of', 'Mordor'),
#  ('Land', 'of', 'Mordor', 'where'),
#  ('Land', 'of', 'Mordor', 'where', 'the'),
#  ('Land', 'of', 'Mordor', 'where', 'the', 'Shadows'),
#  ('of', 'Mordor'),
#  ('of', 'Mordor', 'where'),
#  ('of', 'Mordor', 'where', 'the'),
#  ('of', 'Mordor', 'where', 'the', 'Shadows'),
#  ('of', 'Mordor', 'where', 'the', 'Shadows', 'lie'),
#  ('Mordor', 'where'),
#  ('Mordor', 'where', 'the'),
#  ('Mordor', 'where', 'the', 'Shadows'),
#  ('Mordor', 'where', 'the', 'Shadows', 'lie'),
#  ('Mordor', 'where', 'the', 'Shadows', 'lie', 'He'),
#  ('where', 'the'),
#  ('where', 'the', 'Shadows'),
#  ('where', 'the', 'Shadows', 'lie'),
#  ('where', 'the', 'Shadows', 'lie', 'He'),
#  ('where', 'the', 'Shadows', 'lie', 'He', 'paused'),
#  ('the', 'Shadows'),
#  ('the', 'Shadows', 'lie'),
#  ('the', 'Shadows', 'lie', 'He'),
#  ('the', 'Shadows', 'lie', 'He', 'paused'),
#  ('the', 'Shadows', 'lie', 'He', 'paused', 'and'),
#  ('Shadows', 'lie'),
#  ('Shadows', 'lie', 'He'),
#  ('Shadows', 'lie', 'He', 'paused'),
#  ('Shadows', 'lie', 'He', 'paused', 'and'),
#  ('Shadows', 'lie', 'He', 'paused', 'and', 'then'),
#  ('lie', 'He'),
#  ('lie', 'He', 'paused'),
#  ('lie', 'He', 'paused', 'and'),
#  ('lie', 'He', 'paused', 'and', 'then'),
#  ('lie', 'He', 'paused', 'and', 'then', 'said'),
#  ('He', 'paused'),
#  ('He', 'paused', 'and'),
#  ('He', 'paused', 'and', 'then'),
#  ('He', 'paused', 'and', 'then', 'said'),
#  ('He', 'paused', 'and', 'then', 'said', 'slowly'),
#  ('paused', 'and'),
#  ('paused', 'and', 'then'),
#  ('paused', 'and', 'then', 'said'),
#  ('paused', 'and', 'then', 'said', 'slowly'),
#  ('paused', 'and', 'then', 'said', 'slowly', 'in'),
#  ('and', 'then'),
#  ('and', 'then', 'said'),
#  ('and', 'then', 'said', 'slowly'),
#  ('and', 'then', 'said', 'slowly', 'in'),
#  ('and', 'then', 'said', 'slowly', 'in', 'a'),
#  ('then', 'said'),
#  ('then', 'said', 'slowly'),
#  ('then', 'said', 'slowly', 'in'),
#  ('then', 'said', 'slowly', 'in', 'a'),
#  ('then', 'said', 'slowly', 'in', 'a', 'deep'),
#  ('said', 'slowly'),
#  ('said', 'slowly', 'in'),
#  ('said', 'slowly', 'in', 'a'),
#  ('said', 'slowly', 'in', 'a', 'deep'),
#  ('said', 'slowly', 'in', 'a', 'deep', 'voice'),
#  ('slowly', 'in'),
#  ('slowly', 'in', 'a'),
#  ('slowly', 'in', 'a', 'deep'),
#  ('slowly', 'in', 'a', 'deep', 'voice'),
#  ('slowly', 'in', 'a', 'deep', 'voice', 'This'),
#  ('in', 'a'),
#  ('in', 'a', 'deep'),
#  ('in', 'a', 'deep', 'voice'),
#  ('in', 'a', 'deep', 'voice', 'This'),
#  ('in', 'a', 'deep', 'voice', 'This', 'is'),
#  ('a', 'deep'),
#  ('a', 'deep', 'voice'),
#  ('a', 'deep', 'voice', 'This'),
#  ('a', 'deep', 'voice', 'This', 'is'),
#  ('a', 'deep', 'voice', 'This', 'is', 'the'),
#  ('deep', 'voice'),
#  ('deep', 'voice', 'This'),
#  ('deep', 'voice', 'This', 'is'),
#  ('deep', 'voice', 'This', 'is', 'the'),
#  ('deep', 'voice', 'This', 'is', 'the', 'Masterring'),
#  ('voice', 'This'),
#  ('voice', 'This', 'is'),
#  ('voice', 'This', 'is', 'the'),
#  ('voice', 'This', 'is', 'the', 'Masterring'),
#  ('voice', 'This', 'is', 'the', 'Masterring', 'the'),
#  ('This', 'is'),
#  ('This', 'is', 'the'),
#  ('This', 'is', 'the', 'Masterring'),
#  ('This', 'is', 'the', 'Masterring', 'the'),
#  ('This', 'is', 'the', 'Masterring', 'the', 'One'),
#  ('is', 'the'),
#  ('is', 'the', 'Masterring'),
#  ('is', 'the', 'Masterring', 'the'),
#  ('is', 'the', 'Masterring', 'the', 'One'),
#  ('is', 'the', 'Masterring', 'the', 'One', 'Ring'),
#  ('the', 'Masterring'),
#  ('the', 'Masterring', 'the'),
#  ('the', 'Masterring', 'the', 'One'),
#  ('the', 'Masterring', 'the', 'One', 'Ring'),
#  ('the', 'Masterring', 'the', 'One', 'Ring', 'to'),
#  ('Masterring', 'the'),
#  ('Masterring', 'the', 'One'),
#  ('Masterring', 'the', 'One', 'Ring'),
#  ('Masterring', 'the', 'One', 'Ring', 'to'),
#  ('Masterring', 'the', 'One', 'Ring', 'to', 'rule'),
#  ('the', 'One'),
#  ('the', 'One', 'Ring'),
#  ('the', 'One', 'Ring', 'to'),
#  ('the', 'One', 'Ring', 'to', 'rule'),
#  ('the', 'One', 'Ring', 'to', 'rule', 'them'),
#  ('One', 'Ring'),
#  ('One', 'Ring', 'to'),
#  ('One', 'Ring', 'to', 'rule'),
#  ('One', 'Ring', 'to', 'rule', 'them'),
#  ('One', 'Ring', 'to', 'rule', 'them', 'all'),
#  ('Ring', 'to'),
#  ('Ring', 'to', 'rule'),
#  ('Ring', 'to', 'rule', 'them'),
#  ('Ring', 'to', 'rule', 'them', 'all'),
#  ('Ring', 'to', 'rule', 'them', 'all', 'This'),
#  ('to', 'rule'),
#  ('to', 'rule', 'them'),
#  ('to', 'rule', 'them', 'all'),
#  ('to', 'rule', 'them', 'all', 'This'),
#  ('to', 'rule', 'them', 'all', 'This', 'is'),
#  ('rule', 'them'),
#  ('rule', 'them', 'all'),
#  ('rule', 'them', 'all', 'This'),
#  ('rule', 'them', 'all', 'This', 'is'),
#  ('rule', 'them', 'all', 'This', 'is', 'the'),
#  ('them', 'all'),
#  ('them', 'all', 'This'),
#  ('them', 'all', 'This', 'is'),
#  ('them', 'all', 'This', 'is', 'the'),
#  ('them', 'all', 'This', 'is', 'the', 'One'),
#  ('all', 'This'),
#  ('all', 'This', 'is'),
#  ('all', 'This', 'is', 'the'),
#  ('all', 'This', 'is', 'the', 'One'),
#  ('all', 'This', 'is', 'the', 'One', 'Ring'),
#  ('This', 'is'),
#  ('This', 'is', 'the'),
#  ('This', 'is', 'the', 'One'),
#  ('This', 'is', 'the', 'One', 'Ring'),
#  ('This', 'is', 'the', 'One', 'Ring', 'that'),
#  ('is', 'the'),
#  ('is', 'the', 'One'),
#  ('is', 'the', 'One', 'Ring'),
#  ('is', 'the', 'One', 'Ring', 'that'),
#  ('is', 'the', 'One', 'Ring', 'that', 'he'),
#  ('the', 'One'),
#  ('the', 'One', 'Ring'),
#  ('the', 'One', 'Ring', 'that'),
#  ('the', 'One', 'Ring', 'that', 'he'),
#  ('the', 'One', 'Ring', 'that', 'he', 'lost'),
#  ('One', 'Ring'),
#  ('One', 'Ring', 'that'),
#  ('One', 'Ring', 'that', 'he'),
#  ('One', 'Ring', 'that', 'he', 'lost'),
#  ('One', 'Ring', 'that', 'he', 'lost', 'many'),
#  ('Ring', 'that'),
#  ('Ring', 'that', 'he'),
#  ('Ring', 'that', 'he', 'lost'),
#  ('Ring', 'that', 'he', 'lost', 'many'),
#  ('Ring', 'that', 'he', 'lost', 'many', 'ages'),
#  ('that', 'he'),
#  ('that', 'he', 'lost'),
#  ('that', 'he', 'lost', 'many'),
#  ('that', 'he', 'lost', 'many', 'ages'),
#  ('that', 'he', 'lost', 'many', 'ages', 'ago'),
#  ('he', 'lost'),
#  ('he', 'lost', 'many'),
#  ('he', 'lost', 'many', 'ages'),
#  ('he', 'lost', 'many', 'ages', 'ago'),
#  ('he', 'lost', 'many', 'ages', 'ago', 'to'),
#  ('lost', 'many'),
#  ('lost', 'many', 'ages'),
#  ('lost', 'many', 'ages', 'ago'),
#  ('lost', 'many', 'ages', 'ago', 'to'),
#  ('lost', 'many', 'ages', 'ago', 'to', 'the'),
#  ('many', 'ages'),
#  ('many', 'ages', 'ago'),
#  ('many', 'ages', 'ago', 'to'),
#  ('many', 'ages', 'ago', 'to', 'the'),
#  ('many', 'ages', 'ago', 'to', 'the', 'great'),
#  ('ages', 'ago'),
#  ('ages', 'ago', 'to'),
#  ('ages', 'ago', 'to', 'the'),
#  ('ages', 'ago', 'to', 'the', 'great'),
#  ('ages', 'ago', 'to', 'the', 'great', 'weakening'),
#  ('ago', 'to'),
#  ('ago', 'to', 'the'),
#  ('ago', 'to', 'the', 'great'),
#  ('ago', 'to', 'the', 'great', 'weakening'),
#  ('ago', 'to', 'the', 'great', 'weakening', 'the'),
#  ('to', 'the'),
#  ('to', 'the', 'great'),
#  ('to', 'the', 'great', 'weakening'),
#  ('to', 'the', 'great', 'weakening', 'the'),
#  ('to', 'the', 'great', 'weakening', 'the', 'shadow'),
#  ('the', 'great'),
#  ('the', 'great', 'weakening'),
#  ('the', 'great', 'weakening', 'the'),
#  ('the', 'great', 'weakening', 'the', 'shadow'),
#  ('the', 'great', 'weakening', 'the', 'shadow', 'of'),
#  ('great', 'weakening'),
#  ('great', 'weakening', 'the'),
#  ('great', 'weakening', 'the', 'shadow'),
#  ('great', 'weakening', 'the', 'shadow', 'of'),
#  ('great', 'weakening', 'the', 'shadow', 'of', 'the'),
#  ('weakening', 'the'),
#  ('weakening', 'the', 'shadow'),
#  ('weakening', 'the', 'shadow', 'of'),
#  ('weakening', 'the', 'shadow', 'of', 'the'),
#  ('weakening', 'the', 'shadow', 'of', 'the', 'past'),
#  ('the', 'shadow'),
#  ('the', 'shadow', 'of'),
#  ('the', 'shadow', 'of', 'the'),
#  ('the', 'shadow', 'of', 'the', 'past'),
#  ('the', 'shadow', 'of', 'the', 'past', '67'),
#  ('shadow', 'of'),
#  ('shadow', 'of', 'the'),
#  ('shadow', 'of', 'the', 'past'),
#  ('shadow', 'of', 'the', 'past', '67'),
#  ('shadow', 'of', 'the', 'past', '67', 'of'),
#  ('of', 'the'),
#  ('of', 'the', 'past'),
#  ('of', 'the', 'past', '67'),
#  ('of', 'the', 'past', '67', 'of'),
#  ('of', 'the', 'past', '67', 'of', 'his'),
#  ...]

# %% [markdown]
# Every grams produce every combination of grams from the first number to the last. Pay attention than in large texts, it can generate a large object!

# %% [markdown]
# The advantage of using n-grams is that sometimes we really want to consider our text as bigrams or trigrams given it's context - negation is the best example when we say 'not happy' we can only find that we are negating the word "happy" if we consider the word that precedes it.

# %% [markdown]
# ***
# That's it for NLTK! NLTK is an awesome library that we will use throughout the rest of the sections. During this section we also got familiar with important concepts in Natural Language Processing such as:
# - Tokenization;
# - Part-of-Speech;
# - Stemming and Lemmatization;
# - N-Grams;
# - Stop Words;
# <br>
# <br>
# Give it your best on the exercises!
# ***
